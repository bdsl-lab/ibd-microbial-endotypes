# %%
# Load libraries
from mbiomekit.group_comparison import plotter

# %%
# Plotting
pt = plotter.Plotter()
pt.plot_dunns_test_three_groups(fin_kruskal='data/3-results/group_comparison/kruskal_genus.tsv', fin_dunn='data/3-results/group_comparison/dunn_genus.json',                                
                                x_group='Prevent', y_group='Predict', reference_group='Healthy', n_samples=483,                                
                                output_figure='figures/group_comparison/kw_dunn_genus.pdf', fout='data/3-results/group_comparison/diff_genus.tsv', kruskal_wallis_cutoff=0.05)
